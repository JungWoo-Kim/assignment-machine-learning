# %% [markdown]
# # Linear Regression

# %% [markdown]
# ## import library

# %%
import numpy as np
import matplotlib.image as img
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## load point data for training and testing

# %%
fname_data  = 'assignment_07_data.csv'

data        = np.genfromtxt(fname_data, delimiter=',')
num_data    = data.shape[0]

xx          = np.zeros(num_data)
yy          = np.zeros(num_data)
zz          = np.zeros(num_data)

for i in range(num_data):

    xx[i] = data[i,0]
    yy[i] = data[i,1]
    zz[i] = data[i,2]

# %% [markdown]
# ## plot the data in the three dimensional space

# %%
fig = plt.figure(figsize=(12, 8))

ax1 = plt.subplot(111, projection='3d')
plt.title('data')

ax1.set_xlabel('$x$')
ax1.set_ylabel('$y$')
ax1.set_zlabel('$z$')

ax1.scatter(xx, yy, zz, marker='o', color='blue', alpha=0.2)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## compute the loss function

# %%
def compute_residual(theta, x, y, z):
    # ===== FILL UP THE CODE =====

    residual= z-theta@np.array(1,x,y)

    num_data = num_data + 1

    # ============================
    return residual, num_data

# %%
def compute_loss(theta, x, y, z):
    # ===== FILL UP THE CODE =====

    loss=((theta@np.array(1,x,y)-z)**2).mean()/2

    # ============================
    return loss

# %% [markdown]
# ## compute the gradient for each model parameter (DO NOT COMPUTE THE GRADIENT FOR EACH MODEL PARAMETER, BUT DO COMPUTE THE GRADIENT OF THE MODEL PARAMTER VECTOR)

# %%
def compute_gradient(theta, x, y, z):
    # ===== FILL UP THE CODE =====

    #residual, num_data = compute_residual(theta, x, y, z)

    grad = theta + x + y + z 

    # ============================
    return grad

# %% [markdown]
# ## gradient descent for each model parameter

# %%
num_iteration   = 1000
learning_rate   = 0.01

theta           = np.array((0, 0, 0))
theta_iteration = np.zeros((num_iteration, theta.size))
loss_iteration  = np.zeros(num_iteration)

for i in range(num_iteration):
    # ===== FILL UP THE CODE =====

    theta  = theta - learning_rate * compute_gradient(theta, xx, yy, zz)
    loss    = compute_loss(theta, xx, yy, zz)
    theta_iteration[i] = theta
    loss_iteration[i]   = loss

    # ============================
    print("iteration = %4d, loss = %5.5f" % (i, loss))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-8df1d89447eb> in <module>
#       9     # ===== FILL UP THE CODE =====
#      10
# ---> 11     theta  = theta - learning_rate * compute_gradient(theta, xx, yy, zz)
#      12     loss    = compute_loss(theta, xx, yy, zz)
#      13     theta_iteration[i] = theta
#
# <ipython-input-18-24411ea5bff9> in compute_gradient(theta, x, y, z)
#       4     #residual, num_data = compute_residual(theta, x, y, z)
#       5
# ----> 6     grad = theta + x + y + z
#       7
#       8     # ============================
#
# ValueError: operands could not be broadcast together with shapes (3,) (2500,)

# %%
f = theta[0] + theta[1] * xx + theta[2] * yy

# %% [markdown]
# ## plot the results

# %%
def plot_loss_curve(loss_iteration):

    plt.figure(figsize=(8,6))
    plt.title('loss')
    # ===== FILL UP THE CODE =====

    plt.plot(loss_iteration, '-', color='red')

    # ============================
    plt.tight_layout()
    plt.show()

# %%
def plot_data(xx, yy, zz):
    
    fig = plt.figure(figsize=(12, 8))
    ax  = plt.subplot(111, projection='3d')
    plt.title('data')
    # ===== FILL UP THE CODE =====

    ax.set_xlabel('$x$')
    ax.set_ylabel('$y$')
    ax.set_zlabel('$z$')

    ax.scatter(xx, yy, zz, marker='o', color='blue', alpha=0.2)

    # ============================    
    plt.tight_layout()
    plt.show()

# %%
def plot_model_parameter(theta_iteration):

    plt.figure(figsize=(8,6))
    plt.title('model parameter')
    # ===== FILL UP THE CODE =====

    plt.plot(theta_iteration, '-', color='blue')

    # ============================
    plt.tight_layout()
    plt.show()

# %%
plot_loss_curve(loss_iteration)

# %%
plot_model_parameter(theta_iteration)

# %%
# ===== FILL UP THE CODE =====


# ============================

def plot_surface(XX, YY, ZZ, xx, yy, zz):
    
    fig = plt.figure(figsize=(8, 8))
    ax  = fig.add_subplot(111, projection='3d')
    plt.title('regression surface')
    
    ax  = plt.axes(projection='3d')
    # ===== FILL UP THE CODE =====

    ax.set_xlabel('$x$')
    ax.set_ylabel('$y$')
    ax.set_zlabel('$z$')
    
    ax.scatter(xx, yy, zz, marker='o', color='blue', alpha=0.2)
    ax.scatter(XX, YY, ZZ, marker='f', color='red', alpha=0.2)

    # ============================
    plt.tight_layout()
    plt.show()

# %%
plot_surface(XX, YY, ZZ, xx, yy, zz)

# %% [markdown]
# # * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *

# %% [markdown]
# # * results

# %% [markdown]
# # * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *

# %% [markdown]
# ### # 01. plot the input data in blue point in 3-dimensional space

# %%
plot_data(xx, yy, zz)

# %% [markdown]
# ### # 02. plot the values of the model parameters $\theta_0$ in red curve, $\theta_1$ in green curve, and $\theta_2$ in blue curve over the gradient descent iterations

# %%
plot_model_parameter(theta_iteration)

# %% [markdown]
# ### # 03. plot the loss values $\mathcal{L}(\theta)$ in red curve over the gradient descent iterations

# %%
plot_loss_curve(loss_iteration)

# %% [markdown]
# ### # 04. plot the optimal regression surface $\hat{f}(\theta^*)$ in 3-dimensional space with a given set of data points superimposed

# %%
plot_surface(XX, YY, ZZ, xx, yy, zz)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-086e63f32466> in <module>
# ----> 1 plot_surface(XX, YY, ZZ, xx, yy, zz)
#
# NameError: name 'XX' is not defined
