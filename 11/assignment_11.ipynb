# %% [markdown]
# # K-means clustering

# %% [markdown]
# ## import library

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from matplotlib import cm

# %% [markdown]
# ## load data

# %%
fname_data = 'assignment_11_data.csv'

feature = np.genfromtxt(fname_data, delimiter=',')

x = feature[:,0]
y = feature[:,1]

number_data     = np.size(feature, 0)
number_feature  = np.size(feature, 1)

print('number of data : {}'.format(number_data))
print('number of feature : {}'.format(number_feature))
# Out:
# number of data : 1000
# number of feature : 2

# %% [markdown]
# ## plot the input data

# %%
plt.figure(figsize=(8,8))   
plt.title('input data')

plt.scatter(x, y, c='blue')

plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## compute distance
# ### feature : $n \times m$, center : $1 \times m$, distance : $n \times 1$
# ### $n$ : number of data, $m$ : number of features

# %%
def compute_distance(feature, center):
    
    distance=(sum((feature-center))**2)**0.5

    return distance

# %% [markdown]
# ## compute centroid
# ### feature : $n \times m$, label_feature : $n \times 1$, value_label : $1 \times 1$, centroid : $1 \times m$
# ### $n$ : number of data, $m$ : number of features

# %%
def compute_centroid(feature, label_feature, value_label):
    
    centroid=np.random.uniform(1,maxMovieCnt,len(feature)/len(label_feature))
    for i in range(k):        
        for j in range(len(feature)):
            if index_label_feature[k]==i:
                points=feature[k][0:1]

        centroid[i]=np.mean(points,axis=0)
    
    return centroid

# %% [markdown]
# ## compute label
# ### distance : $n \times k$, label_feature : $n \times 1$
# ### $n$ : number of data, $k$ : number of clusters

# %%
def compute_label(distance):
    
    index_label_feature=np.zeros(len(feature))
    
    for i in range(len(feature)):
        distance=np.zeros(k)
        for j in range(k):
            distance[j]=compute_distance(centroid[j][0:1],feature[0:1])
        cluster=np.argmin(distance)
        index_label_feature[i]=cluster      
    
    return index_label_feature

# %%
# ===================================================
# assign the number of clusters and iterations
k=5
max_iter=10
number_cluster      = k
number_iteration    = max_iter
# ===================================================

# %%
distance            = np.zeros(shape=(number_data, number_cluster))
centroid            = np.zeros(shape=(number_cluster, number_feature))
loss_iteration      = np.zeros(shape=(number_iteration, 1))
centroid_iteration  = np.zeros(shape=(number_iteration, number_cluster, number_feature))

for i in range(number_iteration):
    distance=np.zeros(number_cluster)
    label_cluster=np.zeros(number_cluster)
    #for k in range(len(label_cluster)):
    for k in range(number_cluster):

        distance[k]=compute_distance(centroid[k][0:1],feature[k][0:1])
        cluster=np.argmin(distance)
        label_cluster[i]=cluster
    centroid_old=distance
    
for i in range(number_cluster):
    loss_iteration=centroid_old[i]-centroid[i]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-1a3117e69cd9> in <module>
#      12         distance[k]=compute_distance(centroid[k][0:1],feature[k][0:1])
#      13         cluster=np.argmin(distance)
# ---> 14         label_cluster[i]=cluster
#      15     centroid_old=distance
#      16
#
# IndexError: index 5 is out of bounds for axis 0 with size 5

# %% [markdown]
# ## plot the results

# %%
def plot_data(feature):
    x = feature[:,0]
    y = feature[:,1]

    plt.figure(figsize=(8,8))   
    plt.title('input data')

    plt.scatter(x, y, c='blue')

    plt.tight_layout()
    plt.show()

# %%
def plot_loss_curve(loss_iteration):

    plt.figure(figsize=(8,6))   # USE THIS VALUE for the size of the figure
    plt.title('loss')

    plt.plot(loss_iteration, '-', color='red')

    plt.tight_layout()
    plt.show()

# %%
def plot_centroid(centroid_iteration):

    plt.figure(figsize=(8,8))   # USE THIS VALUE for the size of the figure
    plt.title('centroid')

    x = centroid_iteration[:,0]
    y = centroid_iteration[:,1]
    labels = centroid_iteration[:,2]

    plt.plot(x[i], y[i], "g--")

    plt.tight_layout()
    plt.show()

# %%
def plot_cluster(feature, label_feature, label_cluster):

    plt.figure(figsize=(8,8))   # USE THIS VALUE for the size of the figure
    plt.title('cluster')

    x = feature[:,0]
    y = feature[:,1]

    plt.figure(figsize=(8,8))   
    plt.title('input data')

    plt.scatter(x, y, c=label_feature, cmap=plt.cm.get_cmap('Spectral', 10))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ***

# %% [markdown]
# # results

# %% [markdown]
# ***

# %% [markdown]
# 1. plot the input data

# %%
plot_data(feature)

# %% [markdown]
# ***

# %% [markdown]
# 2. plot the loss over the iterations with the number of clusters being 5

# %%
plot_loss_curve(loss_iteration)

# %% [markdown]
# ***

# %% [markdown]
# 3. plot the trajectory of the centroid for each cluster (blue circle for the initial and red square for the final) with the number of clusters being 5

# %%
plot_centroid(centroid_iteration)

# %% [markdown]
# ***

# %% [markdown]
# 4. plot the final clustering result with the number of clusters being 5

# %%
plot_cluster(feature, label_feature, label_cluster)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-8fa9aa07a6ba> in <module>
# ----> 1 plot_cluster(feature, label_feature, label_cluster)
#
# NameError: name 'label_feature' is not defined

# %% [markdown]
# ***

# %% [markdown]
# 5. plot the loss over the iterations with the number of clusters being 10

# %%
plot_loss_curve(loss_iteration)

# %% [markdown]
# ***

# %% [markdown]
# 6. plot the trajectory of the centroid for each cluster (blue circle for the initial and red square for the final) with the number of clusters being 10

# %%
plot_centroid(centroid_iteration)

# %% [markdown]
# ***

# %% [markdown]
# 7. plot the final clustering result with the number of clusters being 10

# %%
plot_cluster(feature, label_feature, label_cluster)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-8fa9aa07a6ba> in <module>
# ----> 1 plot_cluster(feature, label_feature, label_cluster)
#
# NameError: name 'label_feature' is not defined

# %% [markdown]
# ***
